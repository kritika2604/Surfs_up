# %% [markdown]
# # Importing dependencies

# %%
# Matplotlib Dependencies
# %matplotlib inline
from matplotlib import style
style.use('fivethirtyeight')
import matplotlib.pyplot as plt

# %%
# NumPy and Pandas Dependencies
import numpy as np
import pandas as pd

# %%
# Datetime Dependencies
import datetime as dt

# %% [markdown]
# # Reflect Tables into SQLAlchemy ORM

# %%
# Python SQL toolkit and Object Relational Mapper
import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, func

# %%
engine = create_engine("sqlite:///hawaii.sqlite")

# %%
# reflect an existing database into a new model
Base =  automap_base()

# reflect the tables
Base.prepare(engine, reflect=True)

# %%
# We can view all of the classes that automap found
Base.classes.keys()
# Out:
# ['measurement', 'station']

# %%
# Save references to each table
Measurement = Base.classes.measurement
Station = Base.classes.station

# %%
# Create our session (link) from Python to the DB
session = Session(engine)

# %% [markdown]
# # Exploratory Climate Analysis

# %%
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)
prev_year
# Out:
# datetime.date(2016, 8, 23)

# %%
# Design a query to retrieve the last 12 months of precipitation data and plot the results. 
#Starting from the last data point in the database. 
prev_year = dt.date(2017, 8, 23)

# Calculate the date one year from the last date in data set.
prev_year = dt.date(2017, 8, 23) - dt.timedelta(days=365)

# Perform a query to retrieve the data and precipitation scores
#results=[]
#results = session.query(Measurement.date, Measurement.prcp)
#results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year)
results = session.query(Measurement.date, Measurement.prcp).filter(Measurement.date >= prev_year).all()
df = pd.DataFrame(results,columns=['date','precipitation'])


# Save the query results as a Pandas DataFrame and set the index to the date column
df.set_index(df['date'], inplace=True)
#print(df)
#print(df.to_string(index=False))

# Sort the dataframe by date
df =df.sort_index()
#print(df.to_string(index=False))
# Use Pandas Plotting with Matplotlib to plot the data
df.plot(rot = 'vertical', figsize=(10,5))
# Out:
# <AxesSubplot:xlabel='date'>

# %%
# Use Pandas to calcualte the summary statistics for the precipitation data
df.describe()
# Out:
#        precipitation
# count    2021.000000
# mean        0.177279
# std         0.461190
# min         0.000000
# 25%         0.000000
# 50%         0.020000
# 75%         0.130000
# max         6.700000

# %%
# How many stations are available in this dataset?
session.query(func.count(Station.station)).all()
# Out:
# [(9,)]

# %%
# What are the most active stations?
# List the stations and the counts in descending order.

session.query(Measurement.station, func.count(Measurement.station)).\
    group_by(Measurement.station).order_by(func.count(Measurement.station).desc()).all()
# Out:
# [('USC00519281', 2772),
#  ('USC00519397', 2724),
#  ('USC00513117', 2709),
#  ('USC00519523', 2669),
#  ('USC00516128', 2612),
#  ('USC00514830', 2202),
#  ('USC00511918', 1979),
#  ('USC00517948', 1372),
#  ('USC00518838', 511)]

# %%
# Using the station id from the previous query, calculate the lowest temperature recorded, 
# highest temperature recorded, and average temperature most active station?
session.query(func.min(Measurement.tobs), func.max(Measurement.tobs), func.avg(Measurement.tobs)).\
    filter(Measurement.station == 'USC00519281').all()
# Out:
# [(54.0, 85.0, 71.66378066378067)]

# %%
# Choose the station with the highest number of temperature observations.
# Query the last 12 months of temperature observation data for this station and plot the results as a histogram
results = session.query(Measurement.tobs).\
    filter(Measurement.station == 'USC00519281').\
    filter(Measurement.date >= prev_year).all()
#print(results)
df=pd.DataFrame(results,columns=['tobs'])
#print(df)
df.plot.hist(bins=20)
plt.tight_layout()

# %%
hist = df.plot.hist(bins=20)

# %%
for i in hist.patches:
    print(i.get_bbox().get_points()[0,0],i.get_bbox().get_points()[1,1])
# Out:
# 59.0 5.0
# 60.2 1.0
# 61.4 6.0
# 62.60000000000001 4.0
# 63.800000000000004 3.0
# 65.0 12.0
# 66.20000000000002 15.0
# 67.4 12.0
# 68.6 19.0
# 69.80000000000001 22.0
# 71.0 40.0
# 72.20000000000002 18.0
# 73.4 39.0
# 74.6 33.0
# 75.80000000000001 33.0
# 77.0 53.0
# 78.20000000000002 18.0
# 79.4 11.0
# 80.6 4.0
# 81.80000000000001 4.0

# %%
pip install flask
# Out:
# Requirement already satisfied: flask in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (1.1.2)
# Requirement already satisfied: Jinja2>=2.10.1 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from flask) (2.11.3)
# Requirement already satisfied: click>=5.1 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from flask) (8.0.3)
# Requirement already satisfied: Werkzeug>=0.15 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from flask) (2.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from flask) (2.0.1)
# Requirement already satisfied: colorama in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from click>=5.1->flask) (0.4.4)
# Requirement already satisfied: importlib-metadata in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from click>=5.1->flask) (4.8.2)
# Note: you may need to restart the kernel to use updated packages.Requirement already satisfied: MarkupSafe>=0.23 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from Jinja2>=2.10.1->flask) (1.1.1)
# Requirement already satisfied: typing-extensions>=3.6.4 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->click>=5.1->flask) (3.10.0.2)
# Requirement already satisfied: zipp>=0.5 in c:\users\16479\anaconda3\envs\pythondata\lib\site-packages (from importlib-metadata->click>=5.1->flask) (3.7.0)

# %%
# Write a function called `calc_temps` that will accept start date and end date in the format '%Y-%m-%d' 
# and return the minimum, average, and maximum temperatures for that range of dates

# %% [markdown]
# # Challenge
